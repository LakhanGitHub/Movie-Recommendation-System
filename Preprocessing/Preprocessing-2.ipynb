# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading data from 'The movies data'
#1.credti.csv
#2.movies_metadeta.csv

# %%
credits = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\2.TheMoviesData\credits.csv')

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
meta = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\2.TheMoviesData\movies_metadata.csv')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_5652\838303996.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\2.TheMoviesData\movies_metadata.csv')

# %%
meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
#if coerce, then invalid parsing will be set as NaN, if raise-> then show error or can ignore
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
#extract year
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
#getting only 2017 movies as we alrady have monives upto the year2016 in data1 preprocessing
new_meta = meta.loc[meta.year==2017,['genres','id','title','year']]

# %%
new_meta.head()
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561                                    Justice League  2017.0
# 26565                                    Thor: Ragnarok  2017.0
# 26566                    Guardians of the Galaxy Vol. 2  2017.0
# 30536                               The King's Daughter  2017.0

# %%
#convet id as int
new_meta['id'] = new_meta['id'].astype(int)

# %%
new_meta.dtypes
# Out:
# genres     object
# id          int32
# title      object
# year      float64
# dtype: object

# %%
data = pd.merge(new_meta, credits, on='id')

# %%
pd.set_option('display.max_colwidth', 75)
data.head()
# Out:
#                                                                        genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 4  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12...
#
#        id                                             title    year  \
# 0  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1  141052                                    Justice League  2017.0
# 2  284053                                    Thor: Ragnarok  2017.0
# 3  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 4  245842                               The King's Daughter  2017.0
#
#                                                                          cast  \
# ...

# %%
#convert genres, cast and crew into list from dict

import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %% [markdown]
# # Genres

# %%
#now we will have to take out the individual genres like adventure, action, sci-fi etc

def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name')=='Science Fiction':
            scify = 'Sci-Fi'
            gen.append(scify)
        else:
            gen.append(i.get('name'))
    if gen==[]:
        return np.nan
    else:
        return (st.join(gen)) #gen join them together

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %% [markdown]
# # Actor-1-name

# %%
#now we will have to take out the individual genres like adventure, action, sci-fi etc

def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts==[]:
        return np.nan
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
#now we will have to take out the individual genres like adventure, action, sci-fi etc

def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts==[] or len(casts)<=1:
        return np.nan
    else:
        return (casts[1])
    
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
#now we will have to take out the individual genres like adventure, action, sci-fi etc

def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts==[] or len(casts)<=2:
        return np.nan
    else:
        return (casts[2])
    
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %% [markdown]
# # get Directors from crew

# %%
#now we will have to take out the individual genres like adventure, action, sci-fi etc

def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job')=='Director':
            dt.append(i.get('name'))
    if dt==[]:
        return np.nan
    else:
        return (st.join(dt))
    
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0      Joachim Rønning Espen Sandberg
# 1                         Zack Snyder
# 2                       Taika Waititi
# 3                          James Gunn
# 4                       Sean McNamara
#                     ...
# 526                  Hannaleena Hauru
# 527             Jonathan A. Rosenbaum
# 528          Beth David Esteban Bravo
# 529                      Ravi Udyawar
# 530                     Daisy Asquith
# Name: director_name, Length: 531, dtype: object

# %%
#select only preparing data
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie.head()
# Out:
#                     director_name     actor_1_name    actor_2_name  \
# 0  Joachim Rønning Espen Sandberg      Johnny Depp   Javier Bardem
# 1                     Zack Snyder      Ben Affleck    Henry Cavill
# 2                   Taika Waititi  Chris Hemsworth  Tom Hiddleston
# 3                      James Gunn      Chris Pratt     Zoe Saldana
# 4                   Sean McNamara   Pierce Brosnan    William Hurt
#
#       actor_3_name                      genres_list  \
# 0    Geoffrey Rush  Adventure Action Fantasy Comedy
# 1        Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2   Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3    Dave Bautista   Action Adventure Comedy Sci-Fi
# 4  Benjamin Walker         Fantasy Action Adventure
#
#                                               title
# 0  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                                    Justice League
# 2                                    Thor: Ragnarok
# ...

# %%
movie.isna().sum()
# Out:
# director_name     4
# actor_1_name     22
# actor_2_name     55
# actor_3_name     70
# genres_list       7
# title             0
# dtype: int64

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
#col name should be same as in data1 preprocessing
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie.head()
# Out:
#                     director_name     actor_1_name    actor_2_name  \
# 0  Joachim Rønning Espen Sandberg      Johnny Depp   Javier Bardem
# 1                     Zack Snyder      Ben Affleck    Henry Cavill
# 2                   Taika Waititi  Chris Hemsworth  Tom Hiddleston
# 3                      James Gunn      Chris Pratt     Zoe Saldana
# 4                   Sean McNamara   Pierce Brosnan    William Hurt
#
#       actor_3_name                           genres  \
# 0    Geoffrey Rush  Adventure Action Fantasy Comedy
# 1        Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2   Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3    Dave Bautista   Action Adventure Comedy Sci-Fi
# 4  Benjamin Walker         Fantasy Action Adventure
#
#                                         movie_title
# 0  pirates of the caribbean: dead men tell no tales
# 1                                    justice league
# 2                                    thor: ragnarok
# ...

# %%
#we will use this info later on the tfidvectorizer
movie['combo'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' ' + movie['actor_3_name'] + ' ' + movie['director_name'] + ' ' + movie['genres']

# %%
movie
# Out:
#                       director_name          actor_1_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp
# 1                       Zack Snyder           Ben Affleck
# 2                     Taika Waititi       Chris Hemsworth
# 3                        James Gunn           Chris Pratt
# 4                     Sean McNamara        Pierce Brosnan
# ..                              ...                   ...
# 524                     Jim Strouse      Jessica Williams
# 525                     Farhad Mann         Adelaide Kane
# 526                Hannaleena Hauru        Inka Haapamäki
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips
# 529                    Ravi Udyawar        Sridevi Kapoor
#
#                actor_2_name       actor_3_name  \
# 0             Javier Bardem      Geoffrey Rush
# 1              Henry Cavill          Gal Gadot
# 2            Tom Hiddleston     Cate Blanchett
# 3               Zoe Saldana      Dave Bautista
# ...

# %%
#preprocessing Data1 till 2016
old = pd.read_csv('data1.csv')

# %%
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# ...

# %%
old['combo'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' ' + old['actor_3_name'] + ' ' + old['director_name'] + ' ' + old['genres']

# %%
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title  \
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# ...

# %%
new = old.append(movie)
new
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_5652\215578135.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = old.append(movie)
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# ...

# %%
#drop duplicat titles
new.drop_duplicates(subset = 'movie_title', keep='last', inplace=True)

# %%
new.shape
# Out:
# (5364, 7)

# %%
new.to_csv('new_data.csv', index=False)

# %%
#now we have data till 2017

# %% [markdown]
# # Adding data for 2018-2025 into new_data

# %%
old_data = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\new_data.csv')

# %%
df_2018 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2018.csv')
df_2019 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2019.csv')
df_2020 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2020.csv')
df_2021 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2021.csv')
df_2022 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2022.csv')
df_2023 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2023.csv')
df_2024 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2024.csv')
df_2025 = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\df_2025.csv')

# %%
df_wiki = df_2018.append(df_2019.append(df_2020.append(df_2021.append(df_2022.append(df_2023.append(df_2024.append(df_2025,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6536\3326638254.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wiki = df_2018.append(df_2019.append(df_2020.append(df_2021.append(df_2022.append(df_2023.append(df_2024.append(df_2025,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df_wiki['combo'] = df_wiki['actor_1_name'] + ' ' + df_wiki['actor_2_name'] + ' ' + df_wiki['actor_3_name'] + ' ' + df_wiki['director_name'] + ' ' + df_wiki['genres']
df_wiki.head()
# Out:
#           director_name      actor_1_name            actor_2_name  \
# 0          Adam Robitel         Lin Shaye           Angus Sampson
# 1  Christopher Radcliff     Alex Pettyfer  James Freedson-Jackson
# 2                 Serra       Liam Neeson            Vera Farmiga
# 3          Babak Najafi  Taraji P. Henson    Jahi Di'Allo Winston
# 4         Brett Donowho      Bruce Willis             Cole Hauser
#
#      actor_3_name                       genres              movie_title  \
# 0  Leigh Whannell              Horror Thriller  insidious: the last key
# 1   Emily Althaus               Thriller Drama         the strange ones
# 2  Patrick Wilson      Action Thriller Mystery             the commuter
# 3     Billy Brown        Thriller Action Crime               proud mary
# 4   Shawn Ashmore  Action Drama Crime Thriller         acts of violence
#
#                                                combo
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# ...

# %%
df_wiki.shape
# Out:
# (2591, 7)

# %%
old_data.shape
# Out:
# (5364, 7)

# %%
final_df = old_data.append(df_wiki, ignore_index=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6536\2904319602.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_data.append(df_wiki, ignore_index=True)

# %%
final_df.shape
# Out:
# (7955, 7)

# %%
final_df.to_csv('main_data.csv', index=False)

# %%
final_df.tail()
# Out:
#        director_name       actor_1_name     actor_2_name       actor_3_name  \
# 7950  mez Monteverde        Deva Cassel  Sam Worthington     Ben Mendelsohn
# 7951    Tom Gormican         Jack Black        Paul Rudd   Daniela Melchior
# 7952       Paul Feig     Sydney Sweeney  Amanda Seyfried    Brandon Sklenar
# 7953     Josh Safdie  Timothée Chalamet  Gwyneth Paltrow              Tyler
# 7954    Craig Brewer       Hugh Jackman      Kate Hudson  Michael Imperioli
#
#                            genres     movie_title  \
# 7950                        Drama      zero a. d.
# 7951  Adventure, Horror, Thriller        anaconda
# 7952            Thriller, Mystery   the housemaid
# 7953                        Drama   marty supreme
# 7954               Drama, Romance  song sung blue
#
#                                                   combo
# 7950  Deva Cassel Sam Worthington Ben Mendelsohn mez...
# 7951  Jack Black Paul Rudd Daniela Melchior Tom Gorm...
# ...

# %%
main_data = pd.read_csv(r'E:\Data_Science\Movie Recmentation System\Datasets\main_data.csv')

# %%
main_data.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
main_data['combo'].isnull().sum()
# Out:
# 196

# %%
main_data.shape
# Out:
# (7955, 7)

# %%
#remove duplicate data
main_data = main_data.dropna()

# %%
main_data = main_data.rename(columns={'combo':'comb'})

# %%
main_data.sample()
# Out:
#      director_name    actor_1_name       actor_2_name      actor_3_name  \
# 3233   Robert Wise  Eleanor Parker  Angela Cartwright  Nicholas Hammond
#
#                                       genres         movie_title  \
# 3233  Biography Drama Family Musical Romance  the sound of music
#
#                                                    comb
# 3233  Eleanor Parker Angela Cartwright Nicholas Hamm...

# %%
main_data.to_csv('main_data.csv', index=False)
